# %% [markdown]
# # Air-shower reconstruction using a convolutional neural network
# ## Cosmic-ray observatory
# In this example, we will train a neural network to reconstruct air-shower properties measured by a hypothetic cosmic-ray observatory located at a height of 1400 m. The observatory features a cartesian array of 14 x 14 particle detectors with a distance of 750 m.
# Thus, the measured data contain the simulated detector responses from secondary particles of the cosmic-ray induced air shower that interact with the ground-based observatory.
#
# Each particle detector measures two quantities that are stored in the form of a cartesian image (2D array with 14 x 14 pixels)
# - arrival time `T`: arrival time of the first particles
# - signal `S`: integrated signal
#
# In this task, we are interested in reconstructing the cosmic-ray energy in EeV (exaelectronvolt = $10^{18}~\mathrm{eV}$) using the measured particle footprint and a convolutional neural network.
#
#
# # Preparation:
# **Enable a GPU for this task.**
# Therefore, click:
# *Edit* -> *Notebook settings* -> *select GPU* as *Hardware accelerator*
#
# # References
# The tutorial is inspired by the simulation and the study performed in https://doi.org/10.1016/j.astropartphys.2017.10.006.

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

layers = keras.layers

print("tf", tf.__version__)
# Out:
# tf 2.20.0

# %% [markdown]
# ---
# # Data
# ### Download data
# As a first step, we have to download the simulated air shower data.

# %%
import os
import gdown
url = "https://drive.google.com/u/0/uc?export=download&confirm=HgGH&id=19gOSVQ0mhdjMkm5i2u5NsGrWNBdlhR4F"
output = 'airshowers_mnist.npz'

if os.path.exists(output) == False:
    gdown.download(url, output, quiet=False)

f = np.load(output)
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?export=download&confirm=HgGH&id=19gOSVQ0mhdjMkm5i2u5NsGrWNBdlhR4F
# To: /content/airshowers_mnist.npz
# 100%|██████████| 64.7M/64.7M [00:00<00:00, 67.3MB/s]

# %% [markdown]
# ### Input 1: Arrival times
# Our first input is the arrival times of the first shower particles, measured at the various stations. We normalize the arrival times with respect to the mean and the standard deviation of the arrival time distribution.
# Remember that each input has the shape of 14 x 14, as each station measures a specific arrival time.

# %%
# time map
T = f['time']
T -= np.nanmean(T)
T /= np.nanstd(T)
T[np.isnan(T)] = 0

print(T.shape)
# Out:
# (100000, 14, 14)

# %% [markdown]
# #### Plot four example maps
# To visualize a map of arrival times, we can plot a random example event. Here, the dark blue indicates an early trigger and a bright yellow a late trigger.
# With this information, one can directly get an impression of the shower axis (arrival direction) of the arriving particle shower.

# %%
nsamples=len(T)
random_samples = np.random.choice(nsamples, 4)

def rectangular_array(n=14):
    """ Return x,y coordinates for rectangular array with n^2 stations. """
    n0 = (n - 1) / 2
    return (np.mgrid[0:n, 0:n].astype(float) - n0)

plt.figure(figsize=(9,7))

for i,j in enumerate(random_samples):
    plt.subplot(2,2,i+1)
    footprint=T[j,...]
    xd, yd = rectangular_array()
    mask = footprint != 0
    mask[5, 5] = True
    marker_size = 50 * footprint[mask]
    plot = plt.scatter(xd, yd, c='grey', s=10, alpha=0.3, label="silent")
    circles = plt.scatter(xd[mask], yd[mask], c=footprint[mask],
                          cmap="viridis", alpha=1, label="loud",
                          edgecolors="k", linewidths=0.3)
    cbar = plt.colorbar(circles)
    cbar.set_label('normalized time [a.u.]')
    plt.xlabel("x / km")
    plt.ylabel("y / km")
    plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Input 2: Measured signals
# In the following, we inspect the measured signals of the detectors. Again, we have 14 x 14 measurements (a few are zero as no signal was measured) that form a single event. We process the signal using a logarithmic re-scaling.

# %%
# signal map
S = f['signal']
S = np.log10(1 + S)
S -= np.nanmin(S)
S /= np.nanmax(S)
S[np.isnan(S)] = 0

print(S.shape)
# Out:
# (100000, 14, 14)

# %% [markdown]
# #### Plot four example events

# %%
plt.figure(figsize=(9,7))

for i,j in enumerate(random_samples):
    plt.subplot(2,2,i+1)
    footprint=S[j,...]
    xd, yd = rectangular_array()
    mask = footprint != 0
    mask[5, 5] = True
    marker_size = 130 * footprint[mask] + 20
    plot = plt.scatter(xd, yd, c='grey', s=10, alpha=0.4, label="silent")
    circles = plt.scatter(xd[mask], yd[mask], c=footprint[mask], s=marker_size,
                          cmap="autumn_r", alpha=1, label="loud",
                          edgecolors="k", linewidths=0.4)
    cbar = plt.colorbar(circles)
    cbar.set_label('normalized signals [a.u.]')
    plt.xlabel("x / km")
    plt.ylabel("y / km")
    plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Labels
# Now, we can prepare the targets of our neural network training.

# %%
axis = f['showeraxis']

# %%
core = f['showercore'][:, 0:2]
core /= 750

# %%
# energy - log10(E/eV) in range 3 - 100 EeV
energy = f['energy']
print(energy)
# Out:
# [ 4.00461776  5.99159294  7.49367551 ... 10.81657107  5.07542798
#  43.32910954]

# %% [markdown]
# ---
# #### Training and test data
# We further split the data into one large training set and a smaller test set. This test set is used for the final evaluation of the model and is only used once to ensure an unbiased performance measure.
#
#
# Before, we combine our input `X` by concatenating the maps of arrival times with the maps of signals.

# %%
X = np.stack([T, S], axis=-1)

# %%
X_train, X_test = np.split(X, [-20000])
energy_train, energy_test = np.split(energy, [-20000])

# %% [markdown]
# ---
# ## Define Model
# Now, we will set up a neural network to reconstruct the energy of the particle shower. In this **define step** we will set the architecture of the model.
#
#
# > **Modification section**
# > Feel free to modify the model.
# > For example:
# > *   Change the number of nodes (but remember that the number of weights scales with n x n. Also, the final layer has to have only one node as we are reconstructing the energy, which is a scalar.).
# > *   Change the activation function, e.g., use `relu, tanh, sigmoid, softplus, elu, ` (take care to not use an activation function for the final layer!).
# > *   Add new layers convolutional layers.
# > *   Add new pooling layers, followed by other convolutional layers.
# > *   Add fully-connected layers (remember to use `Flatten()` before).
# > *   Increase the Dropout fraction or place Dropout between several layers if you observe overtraining (validation loss increases).

# %%
model = keras.models.Sequential(name="energy_regression_CNN")
kwargs = dict(kernel_initializer="he_normal", padding="same",)

model.add(layers.Conv2D(16, (3, 3), activation="relu", input_shape=X_train.shape[1:], **kwargs))
model.add(layers.Conv2D(16, (3, 3), activation="relu", input_shape=X_train.shape[1:], **kwargs))
#model.add(layers.AveragePooling2D((2, 2)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3), activation="relu", **kwargs))
model.add(layers.Conv2D(16, (3, 3), activation="relu", input_shape=X_train.shape[1:], **kwargs))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation="relu", **kwargs))
model.add(layers.Conv2D(64, (3, 3), activation="relu", **kwargs))
model.add(layers.MaxPooling2D((2, 2)))
#model.add(layers.GlobalAveragePooling2D())
model.add(layers.Flatten())
model.add(layers.Dropout(0.3))
model.add(layers.Dense(1))

"""
starting net (bias ~ 0.1, resolution ~ 3, loss decreases until ~8 )
model.add(layers.Conv2D(16, (3, 3), activation="relu", input_shape=X_train.shape[1:], **kwargs))
model.add(layers.AveragePooling2D((2, 2)))
model.add(layers.Conv2D(32, (3, 3), activation="relu", **kwargs))
model.add(layers.Flatten())
model.add(layers.Dropout(0.3))
model.add(layers.Dense(1))

replace average pooling with max pooling in starting net: it lower a bit bias (O(10^-2)) and resolution (~2)
add a final Dense layer (after Flatten, before Dropout): it increases considerably the loss (O(10^3,10^2)) and then bias, resolution (not a good model)
the loss does tend to decrease, but after 20 epochs it is still ~500
adding instead a GlobalAveragePooling increases the loss as well, but not so much (after 20 epochs it is O(10))
with 40 epochs it still converges to O(10), and validation and train loss are parallel (with a delta ~0.2)

add a new Conv2D layer with higher dimensionality output (64): small decrease in the final loss (~6 instead of ~8) but validation loss is slightly higher-> add a pooling layer

adding more Conv2D layers (2 Conv2d layer, Pooling, other Conv2d layers, Pooling, etc: does not lower much loss, but results do have better bias and resolution)
"""
# Out:
# '\nstarting net (bias ~ 0.1, resolution ~ 3, loss decreases until ~8 )\nmodel.add(layers.Conv2D(16, (3, 3), activation="relu", input_shape=X_train.shape[1:], **kwargs))\nmodel.add(layers.AveragePooling2D((2, 2)))\nmodel.add(layers.Conv2D(32, (3, 3), activation="relu", **kwargs))\nmodel.add(layers.Flatten())\nmodel.add(layers.Dropout(0.3))\nmodel.add(layers.Dense(1))\n\nreplace average pooling with max pooling in starting net: it lower a bit bias (O(10^-2)) and resolution (~2)\nadd a final Dense layer (after Flatten, before Dropout): it increases considerably the loss (O(10^3,10^2)) and then bias, resolution (not a good model)\nthe loss does tend to decrease, but after 20 epochs it is still ~500\nadding instead a GlobalAveragePooling increases the loss as well, but not so much (after 20 epochs it is O(10))\nwith 40 epochs it still converges to O(10), and validation and train loss are parallel (with a delta ~0.2)\n\nadd a new Conv2D layer with higher dimensionality output (64): small decrease in the final loss (~6 instead of ~8) but validation loss is slightly higher-> add a pooling layer\n'

# %% [markdown]
# We can have a deeper look at our designed model and inspect the number of adaptive parameters by printing the model `summary`.

# %%
print(model.summary())
# Out:
# Model: "energy_regression_CNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_20 (Conv2D)              │ (None, 14, 14, 16)     │           304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 14, 14, 16)     │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 7, 7, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 7, 7, 32)       │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 7, 7, 16)       │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 3, 3, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_24 (Conv2D)              │ (None, 3, 3, 64)       │         9,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_25 (Conv2D)              │ (None, 3, 3, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 1, 1, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_9 (Flatten)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 58,161 (227.19 KB)
#  Trainable params: 58,161 (227.19 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ### Compile
# We now compile the model to prepare it for the training. During the **compile** step, we set a loss/objective function (`mean_squared_error`, as energy reconstruction is a regression task) and set an optimizer. In this case, we use the Adam optimizer with a learning rate of 0.001.
# To monitor the resolution and the bias of the model, we add them as a metric.

# %%
def resolution(y_true, y_pred):
    """ Metric to control for standart deviation """
    mean, var = tf.nn.moments((y_true - y_pred), axes=[0])
    return tf.sqrt(var)


def bias(y_true, y_pred):
    """ Metric to control for standart deviation """
    mean, var = tf.nn.moments((y_true - y_pred), axes=[0])
    return mean

# %%
model.compile(
    loss='mean_squared_error',
    metrics=[bias, resolution],
    optimizer=keras.optimizers.Adam(learning_rate=1e-3))

# %% [markdown]
# ---
# ### Training
# We can now run the training for 20 `epochs` (20-fold iteration over the dataset) using our training data `X_train` and our energy labels `energy_train`.
# For each iteration (calculating the gradients, updating the model parameters), we use 128 samples (`batch_size`).
#
# We furthermore can set the fraction of validation data (initially set to `0.1`) that is used to monitor overtraining.
#
# > **Modification section**
# > Feel free to modify the training procedure, for example:
# >*   Change (increase) the number of `epochs`.
# >*   Modify the batch size via `batch_size`.

# %%
fit = model.fit(
    X_train,
    energy_train,
    batch_size=128,
    epochs=50,
    verbose=2,
    validation_split=0.1,
)
# Out:
# Epoch 1/50
# 563/563 - 13s - 24ms/step - bias: 0.5364 - loss: 106.7576 - resolution: 23.3025 - val_bias: -1.1631e+00 - val_loss: 16.9977 - val_resolution: 25.8123
# Epoch 2/50
# 563/563 - 2s - 4ms/step - bias: 0.3371 - loss: 31.5155 - resolution: 25.2650 - val_bias: 1.0544 - val_loss: 9.8362 - val_resolution: 24.3936
# Epoch 3/50
# 563/563 - 3s - 5ms/step - bias: 0.3382 - loss: 28.1855 - resolution: 25.3498 - val_bias: 0.8996 - val_loss: 8.9569 - val_resolution: 24.1917
# Epoch 4/50
# 563/563 - 3s - 5ms/step - bias: 0.3275 - loss: 26.4286 - resolution: 25.3501 - val_bias: -4.4246e-01 - val_loss: 6.2288 - val_resolution: 25.6898
# Epoch 5/50
# 563/563 - 3s - 4ms/step - bias: 0.3223 - loss: 25.3506 - resolution: 25.4034 - val_bias: 1.1179 - val_loss: 7.0566 - val_resolution: 24.6638
# Epoch 6/50
# 563/563 - 3s - 4ms/step - bias: 0.3321 - loss: 24.4190 - resolution: 25.3968 - val_bias: -2.2136e+00 - val_loss: 12.9382 - val_resolution: 26.6481
# Epoch 7/50
# 563/563 - 3s - 4ms/step - bias: 0.3189 - loss: 24.1971 - resolution: 25.3965 - val_bias: -2.8161e+00 - val_loss: 21.0935 - val_resolution: 27.9351
# Epoch 8/50
# 563/563 - 3s - 6ms/step - bias: 0.3268 - loss: 23.3423 - resolution: 25.4416 - val_bias: -3.0350e+00 - val_loss: 16.5958 - val_resolution: 26.9039
# Epoch 9/50
# 563/563 - 3s - 5ms/step - bias: 0.3062 - loss: 22.5473 - resolution: 25.4263 - val_bias: 0.0239 - val_loss: 4.4415 - val_resolution: 25.1975
# Epoch 10/50
# 563/563 - 3s - 4ms/step - bias: 0.3224 - loss: 22.9887 - resolution: 25.3934 - val_bias: 0.0356 - val_loss: 4.7784 - val_resolution: 25.2566
# Epoch 11/50
# 563/563 - 3s - 5ms/step - bias: 0.3052 - loss: 21.6262 - resolution: 25.4532 - val_bias: 0.6402 - val_loss: 4.9717 - val_resolution: 24.7983
# Epoch 12/50
# 563/563 - 3s - 5ms/step - bias: 0.3184 - loss: 22.4971 - resolution: 25.4012 - val_bias: 1.5875 - val_loss: 10.9768 - val_resolution: 23.8056
# Epoch 13/50
# 563/563 - 3s - 6ms/step - bias: 0.3115 - loss: 21.6901 - resolution: 25.4497 - val_bias: 1.0431 - val_loss: 7.0564 - val_resolution: 24.3297
# Epoch 14/50
# 563/563 - 4s - 8ms/step - bias: 0.3063 - loss: 21.5321 - resolution: 25.4195 - val_bias: 1.2130 - val_loss: 7.5789 - val_resolution: 23.9109
# Epoch 15/50
# 563/563 - 2s - 4ms/step - bias: 0.3069 - loss: 21.3695 - resolution: 25.4386 - val_bias: 0.0569 - val_loss: 3.8901 - val_resolution: 25.6256
# Epoch 16/50
# 563/563 - 2s - 4ms/step - bias: 0.3088 - loss: 20.7909 - resolution: 25.4324 - val_bias: -8.1149e-01 - val_loss: 4.3206 - val_resolution: 25.5869
# Epoch 17/50
# 563/563 - 3s - 6ms/step - bias: 0.2976 - loss: 20.5019 - resolution: 25.4318 - val_bias: 0.5040 - val_loss: 4.2571 - val_resolution: 24.8893
# Epoch 18/50
# 563/563 - 2s - 4ms/step - bias: 0.3043 - loss: 20.1321 - resolution: 25.4586 - val_bias: -2.8738e-01 - val_loss: 3.5796 - val_resolution: 25.1541
# Epoch 19/50
# 563/563 - 2s - 4ms/step - bias: 0.3060 - loss: 20.9270 - resolution: 25.4213 - val_bias: 0.0957 - val_loss: 3.3750 - val_resolution: 25.3513
# Epoch 20/50
# 563/563 - 2s - 4ms/step - bias: 0.2961 - loss: 20.1200 - resolution: 25.4453 - val_bias: -4.6297e-01 - val_loss: 4.7885 - val_resolution: 26.0464
# Epoch 21/50
# 563/563 - 3s - 5ms/step - bias: 0.2958 - loss: 19.6104 - resolution: 25.4582 - val_bias: 1.0622 - val_loss: 5.6447 - val_resolution: 24.3960
# Epoch 22/50
# 563/563 - 3s - 5ms/step - bias: 0.2995 - loss: 19.6116 - resolution: 25.4362 - val_bias: 0.4874 - val_loss: 4.9635 - val_resolution: 24.6795
# Epoch 23/50
# 563/563 - 5s - 8ms/step - bias: 0.2895 - loss: 19.8573 - resolution: 25.4400 - val_bias: -5.7555e-01 - val_loss: 4.2068 - val_resolution: 26.0251
# Epoch 24/50
# 563/563 - 2s - 4ms/step - bias: 0.2881 - loss: 19.3819 - resolution: 25.4481 - val_bias: -9.6200e-01 - val_loss: 5.6001 - val_resolution: 26.3973
# Epoch 25/50
# 563/563 - 2s - 4ms/step - bias: 0.2867 - loss: 19.7381 - resolution: 25.4146 - val_bias: -1.2661e+00 - val_loss: 5.8180 - val_resolution: 26.2053
# Epoch 26/50
# 563/563 - 3s - 6ms/step - bias: 0.2822 - loss: 18.8500 - resolution: 25.4476 - val_bias: -7.4868e-01 - val_loss: 4.2121 - val_resolution: 25.9220
# Epoch 27/50
# 563/563 - 2s - 4ms/step - bias: 0.2760 - loss: 19.1464 - resolution: 25.4332 - val_bias: 1.7230 - val_loss: 8.8616 - val_resolution: 23.8181
# Epoch 28/50
# 563/563 - 2s - 4ms/step - bias: 0.2698 - loss: 19.0212 - resolution: 25.4442 - val_bias: 0.9029 - val_loss: 5.8590 - val_resolution: 24.4936
# Epoch 29/50
# 563/563 - 2s - 4ms/step - bias: 0.2532 - loss: 18.6388 - resolution: 25.3946 - val_bias: -6.5704e-01 - val_loss: 4.0704 - val_resolution: 25.7272
# Epoch 30/50
# 563/563 - 2s - 4ms/step - bias: 0.2472 - loss: 18.7750 - resolution: 25.3950 - val_bias: -5.7220e-01 - val_loss: 4.1589 - val_resolution: 25.5218
# Epoch 31/50
# 563/563 - 3s - 6ms/step - bias: 0.2247 - loss: 18.4992 - resolution: 25.3742 - val_bias: 0.7463 - val_loss: 4.7991 - val_resolution: 24.4085
# Epoch 32/50
# 563/563 - 3s - 4ms/step - bias: 0.2084 - loss: 18.1786 - resolution: 25.3867 - val_bias: 0.6518 - val_loss: 4.2390 - val_resolution: 24.5461
# Epoch 33/50
# 563/563 - 2s - 4ms/step - bias: 0.2010 - loss: 18.3011 - resolution: 25.3795 - val_bias: 0.9213 - val_loss: 5.8038 - val_resolution: 24.2973
# Epoch 34/50
# 563/563 - 2s - 4ms/step - bias: 0.1840 - loss: 18.0629 - resolution: 25.3505 - val_bias: -3.1872e-01 - val_loss: 3.3144 - val_resolution: 25.6075
# Epoch 35/50
# 563/563 - 3s - 4ms/step - bias: 0.1727 - loss: 18.4542 - resolution: 25.3584 - val_bias: -3.4288e-01 - val_loss: 3.7068 - val_resolution: 25.3607
# Epoch 36/50
# 563/563 - 3s - 5ms/step - bias: 0.1595 - loss: 18.4485 - resolution: 25.3191 - val_bias: -2.0483e-01 - val_loss: 3.9792 - val_resolution: 25.2717
# Epoch 37/50
# 563/563 - 2s - 4ms/step - bias: 0.1390 - loss: 18.2062 - resolution: 25.3159 - val_bias: 0.0433 - val_loss: 3.5288 - val_resolution: 24.9912
# Epoch 38/50
# 563/563 - 2s - 4ms/step - bias: 0.1276 - loss: 17.9440 - resolution: 25.3077 - val_bias: -1.3154e+00 - val_loss: 6.2962 - val_resolution: 26.4050
# Epoch 39/50
# 563/563 - 2s - 4ms/step - bias: 0.1132 - loss: 17.6344 - resolution: 25.3059 - val_bias: 0.1903 - val_loss: 3.9108 - val_resolution: 24.6732
# Epoch 40/50
# 563/563 - 3s - 5ms/step - bias: 0.0973 - loss: 17.7098 - resolution: 25.2910 - val_bias: 0.8388 - val_loss: 5.3268 - val_resolution: 24.2121
# Epoch 41/50
# 563/563 - 3s - 5ms/step - bias: 0.0928 - loss: 17.5428 - resolution: 25.3119 - val_bias: 0.6655 - val_loss: 5.0886 - val_resolution: 24.1617
# Epoch 42/50
# 563/563 - 3s - 4ms/step - bias: 0.0810 - loss: 17.6526 - resolution: 25.2831 - val_bias: 1.5897 - val_loss: 10.5071 - val_resolution: 23.1775
# Epoch 43/50
# 563/563 - 2s - 4ms/step - bias: 0.0754 - loss: 17.4607 - resolution: 25.2805 - val_bias: 0.8422 - val_loss: 5.1347 - val_resolution: 24.2559
# Epoch 44/50
# 563/563 - 2s - 4ms/step - bias: 0.0679 - loss: 17.8672 - resolution: 25.2506 - val_bias: -9.0232e-01 - val_loss: 4.7721 - val_resolution: 26.1170
# Epoch 45/50
# 563/563 - 3s - 5ms/step - bias: 0.0586 - loss: 17.7499 - resolution: 25.2314 - val_bias: 0.0438 - val_loss: 3.4877 - val_resolution: 25.0051
# Epoch 46/50
# 563/563 - 3s - 5ms/step - bias: 0.0491 - loss: 17.8783 - resolution: 25.2392 - val_bias: -6.1260e-01 - val_loss: 4.0281 - val_resolution: 25.0909
# Epoch 47/50
# 563/563 - 2s - 4ms/step - bias: 0.0477 - loss: 17.9001 - resolution: 25.2326 - val_bias: -5.5497e-01 - val_loss: 3.7249 - val_resolution: 25.4317
# Epoch 48/50
# 563/563 - 2s - 4ms/step - bias: 0.0373 - loss: 17.4300 - resolution: 25.2479 - val_bias: -1.2129e-01 - val_loss: 3.9358 - val_resolution: 24.8370
# Epoch 49/50
# 563/563 - 2s - 4ms/step - bias: 0.0383 - loss: 17.5347 - resolution: 25.2498 - val_bias: -4.5730e-01 - val_loss: 3.9645 - val_resolution: 24.8963
# Epoch 50/50
# 563/563 - 3s - 5ms/step - bias: 0.0332 - loss: 17.4691 - resolution: 25.2293 - val_bias: -8.1258e-01 - val_loss: 4.0191 - val_resolution: 25.5744

# %% [markdown]
# ### Plot training curves

# %%
fig, ax = plt.subplots(1, figsize=(8,5))
n = np.arange(len(fit.history['loss']))

ax.plot(n, fit.history['loss'], ls='--', c='k', label='loss')
ax.plot(n, fit.history['val_loss'], label='val_loss', c='k')

ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
ax.legend()
ax.semilogy()
ax.grid()
plt.show()

# %% [markdown]
# ---
# ### Performance of the DNN
# After training the model, we can use the test set `X_test` to evaluate the performance of the DNN.
#
# Particularly interesting are the resolution and the bias of the method. A bias close to 0 is desirable. A resolution below 3 EeV can be regarded as good.

# %%
energy_pred = model.predict(X_test, batch_size=128, verbose=1)[:,0]
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step

# %%
diff = energy_pred - energy_test
resolution = np.std(diff)
plt.figure()
plt.hist(diff, bins=100)
plt.xlabel('$E_\mathrm{rec} - E_\mathrm{true}$')
plt.ylabel('# Events')
plt.text(0.95, 0.95, '$\sigma = %.3f$ EeV' % resolution, ha='right', va='top', transform=plt.gca().transAxes)
plt.text(0.95, 0.85, '$\mu = %.1f$ EeV' % diff.mean(), ha='right', va='top', transform=plt.gca().transAxes)
plt.grid()
plt.xlim(-10, 10)
plt.tight_layout()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# <>:5: SyntaxWarning: invalid escape sequence '\m'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\m'
# /tmp/ipykernel_1130/1275510037.py:5: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('$E_\mathrm{rec} - E_\mathrm{true}$')
# /tmp/ipykernel_1130/1275510037.py:7: SyntaxWarning: invalid escape sequence '\s'
#   plt.text(0.95, 0.95, '$\sigma = %.3f$ EeV' % resolution, ha='right', va='top', transform=plt.gca().transAxes)
# /tmp/ipykernel_1130/1275510037.py:8: SyntaxWarning: invalid escape sequence '\m'
#   plt.text(0.95, 0.85, '$\mu = %.1f$ EeV' % diff.mean(), ha='right', va='top', transform=plt.gca().transAxes)

# %% [markdown]
# After estimating the bias and the resolution, we can now inspect the reconstruction via a scatter plot.
#
# Furthermore, we can study the energy dependence of the resolution. With increasing energy, the performance increases due to the lower sampling fluctuation of the ground-based particle detectors and the larger footprints.

# %%
x = [3, 10, 30, 100]
labels = ["3", "10", "30", "100"]

diff = energy_pred - energy_test

# Embedding plot
fig, axes = plt.subplots(1, 2, figsize=(20, 9))
axes[0].scatter(energy_test, energy_pred, s=3, alpha=0.60)
axes[0].set_xlabel(r"$E_{true}\;/\;\mathrm{EeV}$")
axes[0].set_ylabel(r"$E_{DNN}\;/\;\mathrm{EeV}$")

stat_box = r"$\mu = $ %.3f" % np.mean(diff) + " / EeV" + "\n" + "$\sigma = $ %.3f" % np.std(diff) + " / EeV"
axes[0].text(0.95, 0.2, stat_box, verticalalignment="top", horizontalalignment="right",
          transform=axes[0].transAxes, backgroundcolor="w")
axes[0].plot([np.min(energy_test), np.max(energy_test)],
             [np.min(energy_test), np.max(energy_test)], color="red")

sns.regplot(x=energy_test, y=diff / energy_test, x_estimator=np.std, x_bins=12,
            fit_reg=False, color="royalblue", ax=axes[1])
axes[1].tick_params(axis="both", which="major")
axes[1].set(xscale="log")
plt.xticks(x, labels)

axes[1].set_xlabel(r"$E_{true}\;/\;\mathrm{EeV}$")
axes[1].set_ylabel(r"$\sigma_{E}/E$")
axes[1].set_ylim(0, 0.2)
plt.show()
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\s'
# <>:12: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_1130/1444574501.py:12: SyntaxWarning: invalid escape sequence '\s'
#   stat_box = r"$\mu = $ %.3f" % np.mean(diff) + " / EeV" + "\n" + "$\sigma = $ %.3f" % np.std(diff) + " / EeV"
